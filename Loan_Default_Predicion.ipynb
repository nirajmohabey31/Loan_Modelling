# %%
# Importing required libraries
import pandas as pd
import numpy as np
import pandas.util.testing as tm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd2b9772-8697-44aa-9502-abcaeac00d00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd2b9772-8697-44aa-9502-abcaeac00d00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SDT.csv to SDT (1).csv

# %%
import io
loan = pd.read_csv(io.BytesIO(uploaded['SDT.csv']))

# %%
pd.options.display.max_columns = None

# %%
loan.head(5)
# Out:
#                             Name          City State    Zip  \
# 0                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState    CCSC ApprovalDate  ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97        1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97        1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97        1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97        1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97        1997
#
#    Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# ...

# %%
loan.tail(5)
# Out:
#                                   Name        City State    Zip  \
# 149994  BERKS EMERGENCY PHYSICIANS, LL     READING    PA  19604
# 149995             Siding Wizard, Inc.  Belleville    MI  48111
# 149996  MARSH APPRAISAL SERVICES, INC.     FAIRFAX    VA  22032
# 149997  Ohio Cheer Force & Kids Gymnas    Columbus    OH  43228
# 149998  GUADALAJARA MEXICAN RESTAURANT  WAITE PARK    MN  56387
#
#                                   Bank BankState    CCSC ApprovalDate  \
# 149994        CITIZENS BANK NATL ASSOC        RI  621493    30-Oct-06
# 149995  PNC BANK, NATIONAL ASSOCIATION        DE  236118    30-Oct-06
# 149996          CAPITAL ONE NATL ASSOC        VA  541611    30-Oct-06
# 149997    THE HUNTINGTON NATIONAL BANK        OH  812990    30-Oct-06
# 149998      CENTRAL MINNESOTA DEVEL CO        MN  722110    30-May-06
#
#         ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 149994        2007    32     13         1          0           13
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149999 entries, 0 to 149998
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Name               149991 non-null  object
#  1   City               149998 non-null  object
#  2   State              149997 non-null  object
#  3   Zip                149999 non-null  int64
#  4   Bank               149852 non-null  object
#  5   BankState          149851 non-null  object
#  6   CCSC               149999 non-null  int64
#  7   ApprovalDate       149999 non-null  object
#  8   ApprovalFY         149999 non-null  int64
#  9   Term               149999 non-null  int64
#  10  NoEmp              149999 non-null  int64
#  11  NewExist           149999 non-null  int64
#  12  CreateJob          149999 non-null  int64
#  13  RetainedJob        149999 non-null  int64
#  14  FranchiseCode      149999 non-null  int64
# ...

# %%
print(loan.shape)
# Out:
# (149999, 26)

# %%
loan.describe()
# Out:
#                  Zip           CCSC     ApprovalFY           Term  \
# count  149999.000000  149999.000000  149999.000000  149999.000000
# mean    49849.046527  401567.535270    2002.302889      93.010887
# std     31159.635854  256946.069805       5.212507      69.306154
# min         0.000000       0.000000    1962.000000       0.000000
# 25%     20854.000000  236118.000000    1998.000000      57.000000
# 50%     48053.000000  447110.000000    2005.000000      84.000000
# 75%     80003.000000  561612.000000    2006.000000      84.000000
# max     99999.000000  928120.000000    2007.000000     480.000000
#
#                NoEmp       NewExist      CreateJob    RetainedJob  \
# count  149999.000000  149999.000000  149999.000000  149999.000000
# mean        9.313749       1.319535       1.278455       3.685918
# std        78.956632       0.468125      10.958749      27.679464
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
loan.isnull().sum()
# Out:
# Name                      8
# City                      1
# State                     2
# Zip                       0
# Bank                    147
# BankState               148
# CCSC                      0
# ApprovalDate              0
# ApprovalFY                0
# Term                      0
# NoEmp                     0
# NewExist                  0
# CreateJob                 0
# RetainedJob               0
# FranchiseCode             0
# UrbanRural                0
# RevLineCr                23
# LowDoc                    0
# ChgOffDate           109533
# DisbursementDate        225
# DisbursementGross         0
# BalanceGross              0
# MIS_Status              868
# ChgOffPrinGr              0
# GrAppv                    0
# SBA_Appv                  0
# dtype: int64

# %%
loan.nunique()
# Out:
# Name                 140883
# City                  15792
# State                    51
# Zip                   19372
# Bank                   2932
# BankState                52
# CCSC                   1185
# ApprovalDate           2548
# ApprovalFY               23
# Term                    342
# NoEmp                   291
# NewExist                  3
# CreateJob               105
# RetainedJob             167
# FranchiseCode          1034
# UrbanRural                3
# RevLineCr                 7
# LowDoc                    4
# ChgOffDate             4234
# DisbursementDate       1962
# DisbursementGross     38747
# BalanceGross              3
# MIS_Status                2
# ChgOffPrinGr          28116
# GrAppv                 5986
# SBA_Appv               8220
# dtype: int64

# %%
duplicate_rows_df = loan[loan.duplicated()]
print("number of duplicate rows:" , duplicate_rows_df.shape)
# Out:
# number of duplicate rows: (15, 26)

# %%
loan = loan.drop_duplicates()
loan.shape
# Out:
# (149984, 26)

# %%
sns.heatmap(loan.isnull(), cbar=False)
plt.show();

# %%
loan = loan.drop(['ChgOffDate', 'Name'],axis=1 )

# %%
loan.shape
# Out:
# (149984, 24)

# %%
loan['MIS_Status'].fillna(loan['MIS_Status'].value_counts().index[0],inplace = True)
loan['Bank'].fillna(loan['Bank'].mode()[0],inplace = True)
loan['BankState'].fillna(loan['BankState'].mode()[0],inplace = True)
loan['RevLineCr'].fillna(loan['RevLineCr'].mode()[0],inplace = True)
loan.shape
# Out:
# (149984, 24)

# %%
loan.isnull().sum()
# Out:
# City                   1
# State                  2
# Zip                    0
# Bank                   0
# BankState              0
# CCSC                   0
# ApprovalDate           0
# ApprovalFY             0
# Term                   0
# NoEmp                  0
# NewExist               0
# CreateJob              0
# RetainedJob            0
# FranchiseCode          0
# UrbanRural             0
# RevLineCr              0
# LowDoc                 0
# DisbursementDate     225
# DisbursementGross      0
# BalanceGross           0
# MIS_Status             0
# ChgOffPrinGr           0
# GrAppv                 0
# SBA_Appv               0
# dtype: int64

# %%
loan.dropna(axis = 0,inplace=True)

# %%
loan.head(5)
# Out:
#            City State    Zip                           Bank BankState    CCSC  \
# 0    EVANSVILLE    IN  47711               FIFTH THIRD BANK        OH  451120
# 1     NEW PARIS    IN  46526                1ST SOURCE BANK        IN  722410
# 2   BLOOMINGTON    IN  47401        GRANT COUNTY STATE BANK        IN  621210
# 3  BROKEN ARROW    OK  74012  1ST NATL BK & TR CO OF BROKEN        OK       0
# 4       ORLANDO    FL  32801        FLORIDA BUS. DEVEL CORP        FL       0
#
#   ApprovalDate  ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0    28-Feb-97        1997    84      4         2          0            0
# 1    28-Feb-97        1997    60      2         2          0            0
# 2    28-Feb-97        1997   180      7         1          0            0
# 3    28-Feb-97        1997    60      2         1          0            0
# 4    28-Feb-97        1997   240     14         1          7            7
#
# ...

# %%
loan.shape
# Out:
# (149757, 24)

# %%
sns.heatmap(loan.isnull(), cbar=False)
plt.show();

# %%
loan.columns
# Out:
# Index(['City', 'State', 'Zip', 'Bank', 'BankState', 'CCSC', 'ApprovalDate',
#        'ApprovalFY', 'Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob',
#        'FranchiseCode', 'UrbanRural', 'RevLineCr', 'LowDoc',
#        'DisbursementDate', 'DisbursementGross', 'BalanceGross', 'MIS_Status',
#        'ChgOffPrinGr', 'GrAppv', 'SBA_Appv'],
#       dtype='object')

# %%
loan['DisbursementGross'] = loan['DisbursementGross'].str.replace('[\$\,\.]','')
loan['BalanceGross'] = loan['BalanceGross'].str.replace('[\$\,\.]','')
loan['ChgOffPrinGr'] = loan['ChgOffPrinGr'].str.replace('[\$\,\.]','')
loan['GrAppv'] = loan['GrAppv'].str.replace('[\$\,\.]','')
loan['SBA_Appv'] = loan['SBA_Appv'].str.replace('[\$\,\.]','')

# %%
loan.head(5)
# Out:
#            City State    Zip                           Bank BankState    CCSC  \
# 0    EVANSVILLE    IN  47711               FIFTH THIRD BANK        OH  451120
# 1     NEW PARIS    IN  46526                1ST SOURCE BANK        IN  722410
# 2   BLOOMINGTON    IN  47401        GRANT COUNTY STATE BANK        IN  621210
# 3  BROKEN ARROW    OK  74012  1ST NATL BK & TR CO OF BROKEN        OK       0
# 4       ORLANDO    FL  32801        FLORIDA BUS. DEVEL CORP        FL       0
#
#   ApprovalDate  ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0    28-Feb-97        1997    84      4         2          0            0
# 1    28-Feb-97        1997    60      2         2          0            0
# 2    28-Feb-97        1997   180      7         1          0            0
# 3    28-Feb-97        1997    60      2         1          0            0
# 4    28-Feb-97        1997   240     14         1          7            7
#
# ...

# %%
loan['DisbursementGross']= loan['DisbursementGross'].str[:-3]
loan['BalanceGross']= loan['BalanceGross'].str[:-3]
loan['ChgOffPrinGr']= loan['ChgOffPrinGr'].str[:-3]
loan['GrAppv']= loan['GrAppv'].str[:-3]
loan['SBA_Appv']= loan['SBA_Appv'].str[:-3]

# %%
loan.head(5)
# Out:
#            City State    Zip                           Bank BankState    CCSC  \
# 0    EVANSVILLE    IN  47711               FIFTH THIRD BANK        OH  451120
# 1     NEW PARIS    IN  46526                1ST SOURCE BANK        IN  722410
# 2   BLOOMINGTON    IN  47401        GRANT COUNTY STATE BANK        IN  621210
# 3  BROKEN ARROW    OK  74012  1ST NATL BK & TR CO OF BROKEN        OK       0
# 4       ORLANDO    FL  32801        FLORIDA BUS. DEVEL CORP        FL       0
#
#   ApprovalDate  ApprovalFY  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0    28-Feb-97        1997    84      4         2          0            0
# 1    28-Feb-97        1997    60      2         2          0            0
# 2    28-Feb-97        1997   180      7         1          0            0
# 3    28-Feb-97        1997    60      2         1          0            0
# 4    28-Feb-97        1997   240     14         1          7            7
#
# ...

# %%
loan['DisbursementGross']=loan['DisbursementGross'].astype(np.int64)
loan['BalanceGross']=loan['BalanceGross'].astype(np.int64)
loan['ChgOffPrinGr']=loan['ChgOffPrinGr'].astype(np.int64)
loan['GrAppv']=loan['GrAppv'].astype(np.int64)
loan['SBA_Appv']=loan['SBA_Appv'].astype(np.int64)
loan["ApprovalDate"] = pd.to_datetime(loan["ApprovalDate"])
loan["DisbursementDate"] = pd.to_datetime(loan["DisbursementDate"])

# %%
loan.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149757 entries, 0 to 149998
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   City               149757 non-null  object
#  1   State              149757 non-null  object
#  2   Zip                149757 non-null  int64
#  3   Bank               149757 non-null  object
#  4   BankState          149757 non-null  object
#  5   CCSC               149757 non-null  int64
#  6   ApprovalDate       149757 non-null  datetime64[ns]
#  7   ApprovalFY         149757 non-null  int64
#  8   Term               149757 non-null  int64
#  9   NoEmp              149757 non-null  int64
#  10  NewExist           149757 non-null  int64
#  11  CreateJob          149757 non-null  int64
#  12  RetainedJob        149757 non-null  int64
#  13  FranchiseCode      149757 non-null  int64
#  14  UrbanRural         149757 non-null  int64
# ...

# %%
#Changing the MIS_Status Column into numeric
# Chgoff: 1 and PIF: 0
loan['MIS_Status']= loan['MIS_Status'].map({'CHGOFF':1, 'P I F':0})

# %%
loan.MIS_Status.value_counts()
# Out:
# 0    110831
# 1     38926
# Name: MIS_Status, dtype: int64

# %%
loan.FranchiseCode.value_counts()
# Out:
# 1        81110
# 0        63394
# 78760      347
# 68020      147
# 50564      115
#          ...
# 67219        1
# 77890        1
# 75719        1
# 53162        1
# 23115        1
# Name: FranchiseCode, Length: 1031, dtype: int64

# %%
len(loan.loc[loan['FranchiseCode']>1])
# Out:
# 5253

# %%
loan['Franchisecode']=0
loan.loc[loan.FranchiseCode>1,'Franchisecode']=1

# %%
loan.Franchisecode.value_counts()
# Out:
# 0    144504
# 1      5253
# Name: Franchisecode, dtype: int64

# %%
loan.drop(['FranchiseCode'], axis = 1 , inplace = True)

# %%
loan.shape
# Out:
# (149757, 24)

# %%
loan.NewExist.value_counts()
# Out:
# 1    101648
# 2     47984
# 0       125
# Name: NewExist, dtype: int64

# %%
loan.loc[(loan.NewExist !=1) & (loan.NewExist !=2),'NewExist'] = 1

# %%
loan.NewExist.value_counts()
# Out:
# 1    101773
# 2     47984
# Name: NewExist, dtype: int64

# %%
loan.loc[(loan.LowDoc !='N') & (loan.LowDoc !='Y') , 'LowDoc'] = 'N'
loan.LowDoc.value_counts()
# Out:
# N    137716
# Y     12041
# Name: LowDoc, dtype: int64

# %%
loan['LowDoc']=loan['LowDoc'].map({'N':0,'Y':1})

# %%
loan.LowDoc.head(5)
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# Name: LowDoc, dtype: int64

# %%
loan["RevLineCr"] = loan.RevLineCr.map({"N":0,"Y":1,",":1,"T":1,"`":1, "0":0, "1":1})

# %%
loan.RevLineCr.value_counts()
# Out:
# 0    95157
# 1    54600
# Name: RevLineCr, dtype: int64

# %%
corelation = loan.corr()
corelation
# Out:
#                         Zip      CCSC  ApprovalFY      Term     NoEmp  \
# Zip                1.000000 -0.071670   -0.095963  0.148247  0.014723
# CCSC              -0.071670  1.000000    0.578742 -0.259563 -0.040565
# ApprovalFY        -0.095963  0.578742    1.000000 -0.449343 -0.070261
# Term               0.148247 -0.259563   -0.449343  1.000000  0.047374
# NoEmp              0.014723 -0.040565   -0.070261  0.047374  1.000000
# NewExist          -0.080014  0.043608    0.025860 -0.061608 -0.028537
# CreateJob          0.014370  0.019194    0.028186  0.057023  0.023058
# RetainedJob       -0.000329  0.046231    0.067378 -0.004853  0.033362
# UrbanRural        -0.110185  0.499896    0.751178 -0.386023 -0.053582
# RevLineCr          0.006693  0.236065    0.407261 -0.324347 -0.029232
# LowDoc            -0.012621 -0.215317   -0.277217 -0.031433 -0.007963
# DisbursementGross  0.104609 -0.169578   -0.212429  0.493354  0.068719
# ...

# %%
fig,ax = plt.subplots(figsize=(15,10))
sns.heatmap(loan.corr(),cmap='plasma', annot=True)

# %%
sns.pairplot(loan)

# %%
loan.City.value_counts()
# Out:
# LOS ANGELES    1898
# NEW YORK       1577
# MIAMI          1513
# CHICAGO        1396
# HOUSTON        1349
#                ...
# SHAW              1
# LANGSTON          1
# SOUTH WEBER       1
# WENONA            1
# NEOLA             1
# Name: City, Length: 15780, dtype: int64

# %%
loan.City.value_counts().head(10).plot(kind='bar',title = 'City', cmap = 'Set2', fontsize = 16);

# %%
loan.State.value_counts()
# Out:
# CA    19283
# NY    12206
# TX     9811
# FL     9263
# OH     7554
# PA     6270
# IL     6107
# MI     5162
# MA     5023
# NJ     4545
# GA     4195
# WA     3441
# UT     3072
# WI     3037
# AZ     3028
# CO     2953
# MN     2843
# MD     2799
# MO     2769
# NC     2716
# IN     2700
# VA     2429
# CT     2361
# NH     1929
# RI     1583
# OR     1549
# TN     1503
# OK     1409
# KY     1343
# ID     1328
# KS     1313
# NV     1236
# AL     1193
# IA     1164
# LA     1070
# MS     1030
# SC     1027
# MT      934
# ME      866
# AR      833
# VT      792
# NM      667
# NE      549
# WV      494
# DE      458
# ND      454
# HI      390
# SD      330
# WY      283
# DC      234
# AK      229
# Name: State, dtype: int64

# %%
loan.State.value_counts().plot(kind='bar',title = 'State', figsize=(25,15), cmap = 'Set2', fontsize = 16);

# %%
loan.Bank.value_counts()
# Out:
# BANK OF AMERICA NATL ASSOC        28116
# CITIZENS BANK NATL ASSOC          13034
# CAPITAL ONE NATL ASSOC            10610
# JPMORGAN CHASE BANK NATL ASSOC    10349
# WELLS FARGO BANK NATL ASSOC        6358
#                                   ...
# COMMONWEALTH BUSINESS BANK            1
# THE STATE BANK OF WYNNEWOOD           1
# SECURITY BK OF S.W. MISSOURI          1
# LAWSON BANK                           1
# MID-CAROLINA REGIONAL                 1
# Name: Bank, Length: 2929, dtype: int64

# %%
len(loan.Bank.unique())
# Out:
# 2929

# %%
loan.Bank.value_counts().head(25).plot(kind='bar',title = 'Bank', figsize=(25,15),cmap = 'Set2');

# %%
loan.BankState.value_counts()
# Out:
# NC    26947
# RI    14712
# IL    12630
# CA    12429
# VA    11562
# OH    10031
# NY     6270
# DE     5547
# SD     4935
# TX     4771
# UT     3052
# PA     2896
# FL     2877
# OR     1960
# WI     1929
# MN     1845
# GA     1837
# MO     1617
# MA     1467
# MD     1352
# NJ     1101
# CT     1042
# AL     1034
# CO     1013
# WA      950
# MI      897
# IA      857
# IN      787
# MT      782
# KS      774
# OK      768
# SC      716
# DC      700
# MS      681
# NH      631
# AR      605
# KY      563
# VT      516
# NV      483
# TN      478
# LA      435
# ND      421
# AZ      414
# NM      406
# ID      400
# NE      390
# ME      356
# WV      290
# HI      285
# WY      201
# AK       70
# PR       45
# Name: BankState, dtype: int64

# %%
loan.BankState.value_counts().plot(kind='bar',title = 'BankState', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
loan.CCSC.value_counts()
# Out:
# 0         31707
# 722110     3390
# 722211     2888
# 811111     2620
# 561730     2165
#           ...
# 327113        1
# 213115        1
# 421220        1
# 331315        1
# 713920        1
# Name: CCSC, Length: 1184, dtype: int64

# %%
len(loan.CCSC.unique())
# Out:
# 1184

# %%
loan.ApprovalDate.value_counts()
# Out:
# 1997-09-30    466
# 2006-03-17    425
# 2006-03-24    421
# 1997-04-01    418
# 2006-03-31    412
#              ...
# 1981-09-17      1
# 1980-06-18      1
# 1980-07-14      1
# 1981-10-02      1
# 1978-08-31      1
# Name: ApprovalDate, Length: 2525, dtype: int64

# %%
len(loan.ApprovalDate.unique())
# Out:
# 2525

# %%
loan.ApprovalFY.value_counts()
# Out:
# 2006    55296
# 2005    33513
# 1997    23821
# 1998    22726
# 2004     5547
# 2007     3535
# 1984     1959
# 1983     1583
# 1982      524
# 1981      376
# 2003      259
# 1985      151
# 1980      132
# 2001      100
# 1979       98
# 1999       42
# 1978       37
# 2000       34
# 1972       21
# 1973        3
# Name: ApprovalFY, dtype: int64

# %%
len(loan.ApprovalFY.unique())
# Out:
# 20

# %%
loan.ApprovalFY.unique()
# Out:
# array([1997, 1980, 2006, 1998, 1999, 2000, 2001, 1972, 2003, 2004, 1978,
#        1979, 1981, 2005, 1982, 1983, 1973, 1984, 2007, 1985])

# %%
loan.ApprovalFY.min
# Out:
# <bound method Series.min of 0         1997
# 1         1997
# 2         1997
# 3         1997
# 4         1997
#           ...
# 149994    2007
# 149995    2007
# 149996    2007
# 149997    2007
# 149998    2006
# Name: ApprovalFY, Length: 149757, dtype: int64>

# %%
loan.ApprovalFY.max
# Out:
# <bound method Series.max of 0         1997
# 1         1997
# 2         1997
# 3         1997
# 4         1997
#           ...
# 149994    2007
# 149995    2007
# 149996    2007
# 149997    2007
# 149998    2006
# Name: ApprovalFY, Length: 149757, dtype: int64>

# %%
loan.ApprovalFY.value_counts().plot(kind='bar',title = 'ApprovalFY', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
loan.Term.value_counts()
# Out:
# 84     50171
# 60     14385
# 240     8702
# 120     7643
# 300     5192
#        ...
# 314        1
# 372        1
# 435        1
# 421        1
# 342        1
# Name: Term, Length: 342, dtype: int64

# %%
len(loan.Term.unique())
# Out:
# 342

# %%
loan.Term.min(), loan.Term.max()
# Out:
# (0, 480)

# %%
loan.Term.value_counts().head(25).plot(kind='bar',title = 'Term', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
loan.NoEmp.value_counts()
# Out:
# 1       30787
# 2       25985
# 3       16568
# 4       13108
# 5       10286
#         ...
# 310         1
# 2100        1
# 750         1
# 1050        1
# 360         1
# Name: NoEmp, Length: 291, dtype: int64

# %%
len(loan.NoEmp.unique())
# Out:
# 291

# %%
loan.NoEmp.min()
# Out:
# 0

# %%
loan.NoEmp.max
# Out:
# <bound method Series.max of 0          4
# 1          2
# 2          7
# 3          2
# 4         14
#           ..
# 149994    13
# 149995     8
# 149996     4
# 149997     9
# 149998     9
# Name: NoEmp, Length: 149757, dtype: int64>

# %%
loan.NoEmp.value_counts().head(25).plot(kind='bar',title = 'NoEmp', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
loan.NewExist.value_counts()
# Out:
# 1    101773
# 2     47984
# Name: NewExist, dtype: int64

# %%
len(loan.NewExist.unique())
# Out:
# 2

# %%
loan.NewExist.min(), loan.NewExist.max()
# Out:
# (1, 2)

# %%
loan.NewExist.value_counts().plot(kind='bar',title = 'NewExist', figsize=(15,10),cmap = 'Set2', fontsize= 14);

# %%
loan.CreateJob.value_counts()
# Out:
# 0      112870
# 1       11697
# 2        8934
# 3        3781
# 4        2530
#         ...
# 52          1
# 51          1
# 303         1
# 163         1
# 46          1
# Name: CreateJob, Length: 105, dtype: int64

# %%
len(loan.CreateJob.unique())
# Out:
# 105

# %%
loan.CreateJob.min(), loan.CreateJob.max()
# Out:
# (0, 3000)

# %%
loan.CreateJob.value_counts().head(25).plot(kind='bar',title = 'CreateJob', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
loan.LowDoc.value_counts()
# Out:
# 0    137716
# 1     12041
# Name: LowDoc, dtype: int64

# %%
len(loan.LowDoc.unique())
# Out:
# 2

# %%
loan.LowDoc.min(), loan.LowDoc.max()
# Out:
# (0, 1)

# %%
loan.LowDoc.value_counts().plot(kind='bar',title = 'LowDoc',cmap = 'Set2', fontsize= 14);

# %%
loan.UrbanRural.value_counts()
# Out:
# 1    81724
# 0    51370
# 2    16663
# Name: UrbanRural, dtype: int64

# %%
len(loan.UrbanRural.unique())
# Out:
# 3

# %%
loan.UrbanRural.min(), loan.UrbanRural.max()
# Out:
# (0, 2)

# %%
loan.UrbanRural.value_counts().plot(kind='bar',title = 'UrbanRural', figsize=(15,10),cmap = 'Set2', fontsize= 14);

# %%
loan.RevLineCr.value_counts()
# Out:
# 0    95157
# 1    54600
# Name: RevLineCr, dtype: int64

# %%
len(loan.RevLineCr.unique())
# Out:
# 2

# %%
loan.RevLineCr.min(), loan.UrbanRural.max()
# Out:
# (0, 2)

# %%
loan.RevLineCr.value_counts().plot(kind='bar',title = 'RevLineCr', figsize=(15,10),cmap = 'Set2', fontsize= 14);

# %%
loan.MIS_Status.value_counts()
# Out:
# 0    110831
# 1     38926
# Name: MIS_Status, dtype: int64

# %%
len(loan.MIS_Status.unique())
# Out:
# 2

# %%
loan.MIS_Status.min(), loan.MIS_Status.max()
# Out:
# (0, 1)

# %%
loan.MIS_Status.value_counts().plot(kind='bar',title = 'MIS_Status', figsize=(15,10),cmap = 'Set2', fontsize= 14);

# %%
loan.DisbursementDate.value_counts()
# Out:
# 2006-05-31    6220
# 2006-03-31    6039
# 2006-04-30    5848
# 2006-06-30    5262
# 2006-02-28    4893
#               ...
# 1983-08-24       1
# 1998-07-10       1
# 1983-02-16       1
# 1979-09-27       1
# 1982-08-30       1
# Name: DisbursementDate, Length: 1960, dtype: int64

# %%
len(loan.DisbursementDate.unique())
# Out:
# 1960

# %%
loan.DisbursementDate.min(), loan.DisbursementDate.max()
# Out:
# (Timestamp('1971-07-26 00:00:00'), Timestamp('2048-09-17 00:00:00'))

# %%
loan.DisbursementDate.value_counts().head(25).plot(kind='bar',title = 'DisbursementDate', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
loan.DisbursementGross.value_counts()
# Out:
# 50000     10200
# 25000      6981
# 100000     6969
# 10000      5600
# 35000      3090
#           ...
# 119403        1
# 92796         1
# 144023        1
# 37571         1
# 89364         1
# Name: DisbursementGross, Length: 38724, dtype: int64

# %%
len(loan.DisbursementGross.unique())
# Out:
# 38724

# %%
loan.DisbursementGross.min(), loan.DisbursementGross.max()
# Out:
# (0, 4029520)

# %%
loan.DisbursementGross.value_counts().head(25).plot(kind='bar',title = 'DisbursementGross', figsize=(15,10),cmap = 'Set2', fontsize= 14);

# %%
fig = plt.subplots(figsize=(25,15))
sns.distplot(loan.DisbursementGross)

# %%
fig = plt.subplots(figsize=(25,10))
sns.boxplot(loan.DisbursementGross)

# %%
loan.BalanceGross.value_counts()
# Out:
# 0         149755
# 827875         1
# 12750          1
# Name: BalanceGross, dtype: int64

# %%
len(loan.BalanceGross.unique())
# Out:
# 3

# %%
loan.BalanceGross.min(), loan.BalanceGross.max()
# Out:
# (0, 827875)

# %%
loan.BalanceGross.value_counts().plot(kind='bar',title = 'Balance Gross' ,cmap = 'Set2', fontsize= 14);

# %%
loan.ChgOffPrinGr.value_counts()
# Out:
# 0         109578
# 10000        956
# 50000        794
# 25000        435
# 100000       399
#            ...
# 28509          1
# 34752          1
# 38850          1
# 63438          1
# 12614          1
# Name: ChgOffPrinGr, Length: 28027, dtype: int64

# %%
len(loan.ChgOffPrinGr.unique()), loan.ChgOffPrinGr.min(), loan.ChgOffPrinGr.max()
# Out:
# (28027, 0, 1999999)

# %%
loan.ChgOffPrinGr.value_counts().head(25).plot(kind='bar',title = 'Charge Off Amount' ,cmap = 'Set2', fontsize= 14);

# %%
fig = plt.subplots(figsize=(15,10))
sns.distplot(loan.ChgOffPrinGr)

# %%
fig = plt.subplots(figsize=(15,10))
sns.boxplot(loan.ChgOffPrinGr)

# %%
loan.GrAppv.value_counts()
# Out:
# 50000     17477
# 25000     13250
# 10000     12571
# 100000    11103
# 20000      5431
#           ...
# 939000        1
# 293840        1
# 900200        1
# 19670         1
# 153525        1
# Name: GrAppv, Length: 5984, dtype: int64

# %%
len(loan.GrAppv.unique())
# Out:
# 5984

# %%
loan.GrAppv.min(), loan.GrAppv.max()
# Out:
# (200, 4000000)

# %%
loan.GrAppv.value_counts().head(35).plot(kind='bar',title = 'Gross Approved', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
fig = plt.subplots(figsize=(15,10))
sns.distplot(loan.GrAppv)

# %%
fig = plt.subplots(figsize=(15,10))
sns.boxplot(loan.GrAppv)

# %%
 loan.SBA_Appv.value_counts()
# Out:
# 25000     15045
# 5000      11885
# 12500     10820
# 50000      7751
# 10000      4656
#           ...
# 120075        1
# 68880         1
# 380296        1
# 24640         1
# 249142        1
# Name: SBA_Appv, Length: 8213, dtype: int64

# %%
len(loan.SBA_Appv.unique())
# Out:
# 8213

# %%
loan.SBA_Appv.min(), loan.SBA_Appv.max()
# Out:
# (100, 4000000)

# %%
loan.SBA_Appv.value_counts().head(35).plot(kind='bar',title = 'SBA Approved', figsize=(25,15),cmap = 'Set2', fontsize= 14);

# %%
fig = plt.subplots(figsize=(25,15))
sns.distplot(loan.SBA_Appv)

# %%
fig = plt.subplots(figsize=(15,10))
sns.boxplot(loan.SBA_Appv)

# %%
loan.hist(figsize=(25,15), xrot=-0)
plt.show()

# %%
loan.describe(include=['object'])
# Out:
#                City   State                        Bank BankState
# count        149757  149757                      149757    149757
# unique        15780      51                        2929        52
# top     LOS ANGELES      CA  BANK OF AMERICA NATL ASSOC        NC
# freq           1898   19283                       28116     26947

# %%
plot_gross = pd.DataFrame(loan.groupby(['Bank'])['GrAppv'].max().sort_values()[:10]).reset_index()
plot_gross = plot_gross[plot_gross['GrAppv'] > 0]  
plt.subplots(figsize=(8,5))
sns.barplot(x='Bank',y='GrAppv',data=plot_gross,palette='plasma', )
plt.ylabel('Gross Approval($)', fontsize=20)
plt.xticks(rotation=90,fontsize=10)
plt.xlabel('Bank', fontsize=10)
plt.title('Bank with highest Gross Approval', fontsize=10)
plt.show()

# %%
plot_gross1 = pd.DataFrame(loan.groupby(['Bank'])['GrAppv'].max().sort_values()[:10]).reset_index()
plot_gross1 = plot_gross[plot_gross['GrAppv'] > 0]  
plot_gross1.head(10)
plt.subplots(figsize=(8,5))
sns.barplot(x='Bank',y='GrAppv',data=plot_gross,palette='plasma', )
plt.ylabel('Gross Approval($)', fontsize=20)
plt.xticks(rotation=90,fontsize=10)
plt.xlabel('Bank', fontsize=10)
plt.title('Bank with highest Gross Approval', fontsize=10)
plt.show()

# %%
plot_gross2 = pd.DataFrame(loan.groupby(['UrbanRural'])['GrAppv'].max().sort_values()).reset_index()
plot_gross2 = plot_gross2[plot_gross2['GrAppv'] > 1000]  
plt.subplots(figsize=(8,5))
sns.barplot(x='UrbanRural',y='GrAppv',data=plot_gross2,palette='plasma' )
plt.ylabel('Gross Approval($)', fontsize=20)
plt.xticks(fontsize=10)
plt.xlabel('UrbanRural', fontsize=10)
plt.title('UrbanRural with highest Gross Approval', fontsize=10)
plt.show()

# %%
sns.catplot(x="UrbanRural", y="GrAppv",hue='MIS_Status', kind="bar", data=loan, palette='plasma')
plt.title('UrbanRural with highest Gross Approval and MIS_Status', fontsize=12);

# %%
sns.catplot(x="NewExist", y="Term",hue='MIS_Status', kind="bar", data=loan, palette='plasma')
plt.title('NewExist with Term and MIS_Status', fontsize=12);

# %%
sns.catplot(x="LowDoc", y="GrAppv",hue='MIS_Status', kind="bar", data=loan, palette='plasma')
plt.title('LowDoc with GrAppv and MIS_Status', fontsize=12);

# %%
sns.countplot(x="RevLineCr", hue='MIS_Status', data=loan, palette='plasma')
plt.show()

# %%
sns.countplot(x="NewExist", hue='MIS_Status', data=loan, palette='plasma')
plt.show()

# %%
sns.catplot(x="Term", y="DisbursementGross" , hue='MIS_Status', kind='bar' , data=loan, palette='plasma')
plt.show()

# %%
loan = loan.drop(["City","State","Bank","BankState","ApprovalDate","DisbursementDate","BalanceGross","NoEmp"], axis=1)

# %%
print(loan.head())
# Out:
#      Zip    CCSC  ApprovalFY  Term  NewExist  CreateJob  RetainedJob  \
# 0  47711  451120        1997    84         2          0            0
# 1  46526  722410        1997    60         2          0            0
# 2  47401  621210        1997   180         1          0            0
# 3  74012       0        1997    60         1          0            0
# 4  32801       0        1997   240         1          7            7
#
#    UrbanRural  RevLineCr  LowDoc  DisbursementGross  MIS_Status  ChgOffPrinGr  \
# 0           0          0       1              60000           0             0
# 1           0          0       1              40000           0             0
# 2           0          0       0             287000           0             0
# 3           0          0       1              35000           0             0
# 4           0          0       0             229000           0             0
#
#    GrAppv  SBA_Appv  Franchisecode
# 0   60000     48000              0
# ...

# %%
print(loan.shape)
# Out:
# (149757, 16)

# %%
loan
# Out:
#           Zip    CCSC  ApprovalFY  Term  NewExist  CreateJob  RetainedJob  \
# 0       47711  451120        1997    84         2          0            0
# 1       46526  722410        1997    60         2          0            0
# 2       47401  621210        1997   180         1          0            0
# 3       74012       0        1997    60         1          0            0
# 4       32801       0        1997   240         1          7            7
# ...       ...     ...         ...   ...       ...        ...          ...
# 149994  19604  621493        2007    32         1          0           13
# 149995  48111  236118        2007    24         1          3            5
# 149996  22032  541611        2007    84         1          2            4
# 149997  43228  812990        2007    60         1          0            0
# 149998  56387  722110        2006   240         1          5            9
#
#         UrbanRural  RevLineCr  LowDoc  DisbursementGross  MIS_Status  \
# ...

# %%
x = loan.drop("MIS_Status", axis=1)

# %%
y = loan["MIS_Status"]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif

# %%
bestfeatures = SelectKBest(score_func=f_classif , k=15)
fit = bestfeatures.fit(x,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']

# %%
print(featureScores.nlargest(15,"Score"))
# Out:
#              Features         Score
# 11       ChgOffPrinGr  35517.636852
# 3                Term  25477.143099
# 7          UrbanRural   5884.501530
# 2          ApprovalFY   3817.651926
# 13           SBA_Appv   2507.181004
# 9              LowDoc   2300.410028
# 12             GrAppv   2075.641517
# 1                CCSC   1998.805996
# 8           RevLineCr   1602.496876
# 10  DisbursementGross   1577.395280
# 14      Franchisecode    247.050030
# 4            NewExist    135.747652
# 6         RetainedJob     11.033002
# 0                 Zip      6.456127
# 5           CreateJob      0.311966

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
feature = model.fit(x,y)
print(model.feature_importances_)
# Out:
# [0.02011644 0.01796964 0.04366974 0.26318142 0.00418469 0.00616043
#  0.00880663 0.0286471  0.00662767 0.00609027 0.01724551 0.53943399
#  0.01801238 0.01870526 0.00114882]

# %%
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(16).plot(kind='barh')
plt.show()

# %%
loan = loan.drop(["ChgOffPrinGr","RetainedJob","RevLineCr","CreateJob","NewExist","Franchisecode"],axis=1)

# %%
loan.head()
# Out:
#      Zip    CCSC  ApprovalFY  Term  UrbanRural  LowDoc  DisbursementGross  \
# 0  47711  451120        1997    84           0       1              60000
# 1  46526  722410        1997    60           0       1              40000
# 2  47401  621210        1997   180           0       0             287000
# 3  74012       0        1997    60           0       1              35000
# 4  32801       0        1997   240           0       0             229000
#
#    MIS_Status  GrAppv  SBA_Appv
# 0           0   60000     48000
# 1           0   40000     32000
# 2           0  287000    215250
# 3           0   35000     28000
# 4           0  229000    229000

# %%
loan.shape
# Out:
# (149757, 10)

# %%
loan = loan[["Zip", "CCSC", "ApprovalFY","Term","UrbanRural","LowDoc","DisbursementGross","GrAppv","SBA_Appv","MIS_Status"]]
loan.columns.index = range(loan.shape[1])

# %%
x=loan.drop("MIS_Status",axis=1)
y=loan["MIS_Status"]

# %%
np.random.seed(42)

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
x_normalized = pd.DataFrame(x_scaled)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, stratify=y, random_state=0)

# %%
x_train
# Out:
#           Zip    CCSC  ApprovalFY  Term  UrbanRural  LowDoc  \
# 91002   89822       0        1998   238           0       0
# 120417  97068  441310        2006    72           1       0
# 93976   14301  423420        2006    84           1       0
# 121971  91010  422330        1998   300           0       0
# 21898   95688  518210        2005    63           1       0
# ...       ...     ...         ...   ...         ...     ...
# 132900   6468  445299        2006    84           2       0
# 116690  85281  332813        1998   300           0       0
# 146547  59442  811121        1998   180           0       0
# 44622   63841  316213        1997    36           0       0
# 36068   44122  541611        2005    84           1       0
#
#         DisbursementGross  GrAppv  SBA_Appv
# 91002              318500  318500    238875
# 120417              68000   20000     10000
# 93976               57146   50000     25000
# 121971             263000  263000    197250
# ...

# %%
y_train
# Out:
# 91002     1
# 120417    0
# 93976     0
# 121971    0
# 21898     1
#          ..
# 132900    0
# 116690    0
# 146547    0
# 44622     0
# 36068     0
# Name: MIS_Status, Length: 104829, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn import metrics as m
acc_log_reg_train = log_reg.score(x_train, y_train) * 100
print("Percentange of training Score of Logistic model is ",acc_log_reg_train)
# Out:
# Percentange of training Score of Logistic model is  82.41994104684773

# %%
y_pred = log_reg.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
acc_log_reg = accuracy_score(y_test, y_pred) * 100
print("Percentage of accuracy score: ",acc_log_reg)
# Out:
# Percentage of accuracy score:  82.23824786324786

# %%
from sklearn.metrics import roc_auc_score
ROC_log_reg = roc_auc_score(y_test, y_pred)
print("ROC_AUC_score : ", ROC_log_reg)
# Out:
# ROC_AUC_score :  0.7167767268831439

# %%
cf_matrix = m.confusion_matrix(y_test, y_pred, labels = [0, 1])
cf_matrix
# Out:
# array([[31146,  2104],
#        [ 5876,  5802]])

# %%
labels = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, cmap = "plasma", fmt = "")
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors = 21, weights = 'uniform', metric = 'euclidean')
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=21, p=2,
#                      weights='uniform')

# %%
acc_knn_model_train = log_reg.score(x_train, y_train) * 100
print("Percentange of training Score of KNN model is ",acc_log_reg_train)
# Out:
# Percentange of training Score of KNN model is  82.41994104684773

# %%
y_pred = log_reg.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
acc_knn_model = accuracy_score(y_test, y_pred) * 100
print("Percentage of accuracy score: ",acc_knn_model)
# Out:
# Percentage of accuracy score:  82.23824786324786

# %%
ROC_knn_model = roc_auc_score(y_test, y_pred)
print("ROC_AUC_score : ", ROC_knn_model)
# Out:
# ROC_AUC_score :  0.7167767268831439

# %%
cf_matrix = m.confusion_matrix(y_test, y_pred, labels = [0, 1])
cf_matrix
# Out:
# array([[31146,  2104],
#        [ 5876,  5802]])

# %%
labels = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, cmap = "plasma", fmt = "")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(random_state = 42)
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
acc_dt_model_train = dt_model.score(x_train, y_train) * 100
print("Percentage of training score: ",acc_dt_model_train)
# Out:
# Percentage of training score:  100.0

# %%
y_pred = dt_model.predict(x_test)
y_pred[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
acc_dt_model = accuracy_score(y_test, y_pred)*100
print("Percentage of accuracy score: ",acc_dt_model)
# Out:
# Percentage of accuracy score:  91.83137464387464

# %%
prec_rec_dt_model = m.classification_report(y_test, y_pred, labels = [0, 1])
print(prec_rec_dt_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     33250
#            1       0.85      0.84      0.84     11678
#
#     accuracy                           0.92     44928
#    macro avg       0.89      0.89      0.89     44928
# weighted avg       0.92      0.92      0.92     44928

# %%
ROC_dt_model = roc_auc_score(y_test, y_pred)
print("ROC_AUC_score : ", ROC_dt_model)
# Out:
# ROC_AUC_score :  0.8927839173202744

# %%
cf_matrix = m.confusion_matrix(y_test, y_pred, labels = [0, 1])
cf_matrix
# Out:
# array([[31453,  1797],
#        [ 1873,  9805]])

# %%
labels = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, cmap = "plasma", fmt = "")
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

# %%
N_model = GaussianNB()
N_model.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
acc_N_model_train = N_model.score(x_train, y_train) * 100
print("Percentage of training score: ",acc_N_model_train)
# Out:
# Percentage of training score:  49.8945902374343

# %%
y_pred = N_model.predict(x_test)
y_pred[:5]
# Out:
# array([1, 1, 1, 1, 0])

# %%
acc_N_model = accuracy_score(y_test, y_pred)*100
print("Percentage of accuracy score : ",acc_N_model)
# Out:
# Percentage of accuracy score :  49.90429131054131

# %%
prec_rec_N_model = m.classification_report(y_test, y_pred, labels = [0, 1])
print(prec_rec_N_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.37      0.52     33250
#            1       0.33      0.87      0.47     11678
#
#     accuracy                           0.50     44928
#    macro avg       0.61      0.62      0.50     44928
# weighted avg       0.74      0.50      0.51     44928

# %%
ROC_N_model = roc_auc_score(y_test, y_pred)
print("ROC_AUC_score : ", ROC_N_model)
# Out:
# ROC_AUC_score :  0.6197430474628085

# %%
cf_matrix = m.confusion_matrix(y_test, y_pred, labels = [0, 1])
cf_matrix
# Out:
# array([[12248, 21002],
#        [ 1505, 10173]])

# %%
labels = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, cmap = "plasma", fmt = "")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state = 42, criterion = "entropy")
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
acc_rf_model_train = rf_model.score(x_train, y_train) * 100
print("Percentage of training score: ",acc_rf_model_train)
# Out:
# Percentage of training score:  99.99809213099428

# %%
y_pred = rf_model.predict(x_test)
y_pred[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
acc_rf_model = accuracy_score(y_test, y_pred)* 100
print("Percentage of accuracy score: ",acc_rf_model)
# Out:
# Percentage of accuracy score:  94.27973646723646

# %%
prec_rec_rf_model = m.classification_report(y_test, y_pred, labels = [0, 1])
print(prec_rec_rf_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     33250
#            1       0.89      0.89      0.89     11678
#
#     accuracy                           0.94     44928
#    macro avg       0.93      0.92      0.93     44928
# weighted avg       0.94      0.94      0.94     44928

# %%
ROC_rf_model = roc_auc_score(y_test, y_pred)
print("ROC_AUC_score : ", ROC_rf_model)
# Out:
# ROC_AUC_score :  0.9247975925427543

# %%
cf_matrix = m.confusion_matrix(y_test, y_pred, labels = [0, 1])
cf_matrix
# Out:
# array([[31996,  1254],
#        [ 1316, 10362]])

# %%
labels = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, cmap = "plasma", fmt = "")
plt.show()

# %%
labels=['log_reg','N_model','dt_model','knn_model','rf_model']
Acc_Test=[acc_log_reg,acc_N_model,acc_dt_model,acc_knn_model,acc_rf_model]
plt.bar(labels,Acc_Test)
plt.xlabel('Models')
plt.ylabel('Test set accuracies')
plt.show()

# %%
Acc_Train=[acc_log_reg_train,acc_N_model_train,acc_dt_model_train,acc_knn_model_train,acc_rf_model_train]
plt.bar(labels,Acc_Train)
plt.xlabel('Models')
plt.ylabel('Training set accuracies')
plt.show()

# %%
PS=['prec_rec_log_reg','prec_rec_N.model','prec_rec_dt_model','prec_rec_knn_model','prec_rec_rf_model']
plt.bar(labels,PS)
plt.xlabel('Models')
plt.ylabel('Precision Scores')
plt.show()

# %%
ROC=['ROC_log_reg','ROC_N_model','ROC_dt_model','ROC_knn_model','ROC_rf_model']
plt.bar(labels,ROC)
plt.xlabel('model')
plt.ylabel('ROC_AUC_scores')
plt.show()
